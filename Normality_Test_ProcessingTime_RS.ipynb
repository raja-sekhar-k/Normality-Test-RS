# %% [markdown]
# ## Normality Test
# ## The processing time of purchase orders are given. Is the processing time normally destributed?

# %%
import pandas as pa
from scipy import stats as mystats
import matplotlib.pyplot as myplot

# %%
myData = pa.read_csv('.\datasets\PO_Processing.csv')

# %%
myData
# Out:
#     Processing_Time
# 0                49
# 1                46
# 2                56
# 3                56
# 4                68
# 5                46
# 6                65
# 7                21
# 8                10
# 9                26
# 10               35
# 11               25
# 12               54
# 13              105
# 14                2
# 15               39
# 16               92
# 17               44
# 18               30
# 19               36
# 20               42
# 21               43
# 22               83
# 23               68
# 24               45
# 25              102
# 26                5
# 27               54
# 28               20
# 29               52
# ..              ...
# 70               39
# 71               61
# 72               93
# 73               48
# 74                3
# 75               55
# 76               26
# 77               61
# 78               55
# 79               77
# 80               51
# 81               50
# 82                2
# ...

# %%
PT = myData.Processing_Time

# %%
PT
# Out:
# 0      49
# 1      46
# 2      56
# 3      56
# 4      68
# 5      46
# 6      65
# 7      21
# 8      10
# 9      26
# 10     35
# 11     25
# 12     54
# 13    105
# 14      2
# 15     39
# 16     92
# 17     44
# 18     30
# 19     36
# 20     42
# 21     43
# 22     83
# 23     68
# 24     45
# 25    102
# 26      5
# 27     54
# 28     20
# 29     52
#      ...
# 70     39
# 71     61
# 72     93
# 73     48
# 74      3
# 75     55
# 76     26
# 77     61
# 78     55
# 79     77
# 80     51
# 81     50
# 82      2
# 83     60
# 84     44
# 85     41
# 86     10
# 87     57
# 88     47
# 89     55
# 90      1
# 91     61
# 92     60
# 93      4
# 94     51
# 95     36
# 96     37
# 97     12
# 98     42
# 99     72
# Name: Processing_Time, Length: 100, dtype: int64

# %%
mystats.probplot(PT, plot = myplot)
myplot.show()

# %%
mystats.mstats.normaltest(PT)
# Out:
# NormaltestResult(statistic=0.3396526182225922, pvalue=0.8438113662149449)

# %%
# P Value is more than 0.05 (P>0.05) , So the distribution seems to be normal
